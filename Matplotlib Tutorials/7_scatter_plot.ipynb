# %% [markdown]
# # Matplotlib Scatter
#
# To draw scatter plot we use scatter() function.
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
# Show the Relationship between study time and exam score.

import matplotlib.pyplot as plt

studies_hours = [1, 2, 3, 4, 5, 6, 7, 8]
exam_scores = [52, 57, 62, 67, 72, 75, 80, 85]

plt.scatter(studies_hours, exam_scores, label = "Student Data")

plt.xlabel("Hours Studied")
plt.ylabel("Exam Scores")
plt.title("Relationship between study time and exam score")
plt.legend()

plt.show()

# %%
# Show the Relationship between age of the cars and their speed.

car_age = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
car_speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

plt.scatter(car_age, car_speed, color = "red", label = "Cars Data")

plt.xlabel("Ages of Cars")
plt.ylabel("Speed of Cars")
plt.title("Relationship between age of the cars and their speed")
plt.legend()

plt.show()

# %% [markdown]
# ## Compare Plots
#
# In the example above, there seems to be a relationship between speed and age,
#
# But in this example we will plot the observation of relationship between speed and age for two days and will compare them.

# %%
# Day one
car_age = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
car_speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
plt.scatter(car_age, car_speed, label = "Day One Data")

# Day two
car_age = [2, 8, 1, 15, 8, 12, 9, 7, 3, 11, 4, 7, 14]
car_speed = [100, 105, 84, 105, 90, 99, 95, 94, 100, 79, 112, 91, 80]
plt.scatter(car_age, car_speed, label = "Day Two Data")


plt.xlabel("Ages of Cars")
plt.ylabel("Speed of Cars")
plt.title("Relationship between age of the cars and their speed")
plt.legend()

plt.show()

# %% [markdown]
# ## ColorMap
#
# The Matplotlib module has a number of available colormaps.
#
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.

# %% [markdown]
# ### How to Use the ColorMap
#
# We can specify the colormap with the keyword argument (cmap) with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.
#
# In addition we have to create an array with values (from 0 to 100), one value for each point in the scatter plot:

# %%
car_age = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
car_speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

# Create a color array
colors_arr = [0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100]

# Specify a colormap in the scatter plot
plt.scatter(car_age, car_speed, c= colors_arr, cmap= "viridis" )

# To include the colormap in the drawing we use the plt.colorbar() statement.
plt.colorbar()

plt.xlabel("Ages of Cars")
plt.ylabel("Speed of Cars")
plt.title("Relationship between age of the cars and their speed")

plt.show()

# %%
car_age = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
car_speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

# Create a color array
colors_arr = [0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100]

# Specify a colormap in the scatter plot
plt.scatter(car_age, car_speed, c= colors_arr, cmap= "Oranges" )

# To include the colormap in the drawing we use the plt.colorbar() statement.
plt.colorbar()

plt.xlabel("Ages of Cars")
plt.ylabel("Speed of Cars")
plt.title("Relationship between age of the cars and their speed")

plt.show()

# %% [markdown]
# ## Size of dots
#
# We can change the size of the dots with the s argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis.

# %%
car_age = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
car_speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
size_arr = [20,50,100,200,500,1000,60,90,10,300,600,800,75]

plt.scatter(car_age, car_speed, s= size_arr)

plt.xlabel("Ages of Cars")
plt.ylabel("Speed of Cars")
plt.title("Relationship between age of the cars and their speed")


plt.show()
