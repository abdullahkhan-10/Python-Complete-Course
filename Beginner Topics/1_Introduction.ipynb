# %% [markdown]
# # Python Introduction

# %% [markdown]
# Python is Popular programming language which is used for Data Science, Artificial Intelligence, Software Development, Mathematics, Statistics and much more. It was created by Guido van Rossum, and released in 1991.

# %% [markdown]
# ## What Python can do

# %% [markdown]
# 1. Python can be used on a server to create web applications.
# 2. Python can be used for Data Manipulation and Visualization.
# 3. Python can connect to database systems. It can also read and modify files.
# 4. Python can be used to handle big data and perform complex mathematics.
# 5. Python can be used for advance data science, Artificial Intelligence and Machine Learning

# %% [markdown]
# ## Python Libraries and Framworks

# %% [markdown]
# ### Most Important Industry Standard Stack

# %% [markdown]
# 1. NumPy            (Numerical computing, arrays)
# 2. Pandas           (Data manipulation & analysis)
# 3. Matplotlib       (Data Visualization)
# 4. Seaborn/Plotly   (Data Visualization)
# 5. Scikit-learn            (Machine Learning)
# 6. TensorFlow/ PyTorch/ Keras   (Artificial Inteigence & Deep Learning)
# 7. Statsmodels/ Scipy            (Statistical modeling)
# 8. BeautifulSoup/ Scrapy/ Selenium  (Web Scraping)
# 9. Transformers (Hugging Face)  (Natural Language Processing)
# 10. FastAPI/ Flask/ django        (DEPLOYMENT & PRODUCTION)

# %% [markdown]
# ## First Line of Code

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
print("My name is Abdullah Khan")
# Out:
# My name is Abdullah Khan

# %%
print("I am From District Khyber, Pakistan")
# Out:
# I am From District Khyber, Pakistan
