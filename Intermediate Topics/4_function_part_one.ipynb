# %% [markdown]
# # Python Functions
# A function is a block of code which only runs when it is called.
# A function can return data as a result.
#
# A function helps avoiding code repetition.

# %%
def greeting():
    print("Hi, Abdullah khan")

greeting()
# Out:
# Hi, Abdullah khan

# %% [markdown]
# ### Function Names
# A function name must start with a letter or underscore. The name can only contain letters, numbers, and underscores.
#
# Function names are case-sensitive (myFunction and myfunction are different)

# %%
def add_number():
    num1 = 10
    num2 = 300
    print(num1 + num2)
add_number()
# Out:
# 310

# %% [markdown]
# ### Return Values
# Functions can send data back to the code that called them using the return statement.
#
# When a function reaches a return statement, it stops executing and sends the result back:

# %%
def greeting():
    return("Abdullah khan")

# With return value we can store the function in variable.
person = greeting()
print(f"Hi, {person}")

# If a function doesn't have a return statement, it returns None by default.
# Out:
# Hi, Abdullah khan

# %%
# Return function with arguments
def add_numbers(x, y):
  return x + y

result = add_numbers(55, 32)
print(result)
# Out:
# 87

# %% [markdown]
# ### Why Functions
# Imagine you need to convert temperatures from Fahrenheit to Celsius several times in your program.
#
# Without functions, you would have to write the same calculation code repeatedly:

# %%
def far_to_cel(farhrenheit):
    return(farhrenheit - 32) * 5 / 9

far_to_cel(104)
# Out:
# 40.0

# %% [markdown]
# ### pass Statement
# Function definitions cannot be empty. If you need to create a function placeholder without any code, use the pass statement:

# %%
def my_function():
  pass

# %% [markdown]
# # Function Arguments
# Arguments are specified after the function name, inside the parentheses. You can add as many arguments as you want, just separate them with a comma.

# %%
# A parameter is the variable listed inside the parentheses in the function definition.

def my_name(first_name):          # first_name is a parameter
    print(f"{first_name} Khan")

my_name("Abdullah")     # "Abdullah" is an argument

# An argument is the actual value that is sent to the function when it is called
# Out:
# Abdullah Khan

# %% [markdown]
# ### Number of Arguments
# By default, a function must be called with the correct number of arguments.
#
# If your function expects 2 arguments, you must call it with exactly 2 arguments.

# %%
def full_name(first_name, last_name):
    print(first_name + " "+ last_name)

full_name("Abdullah", "Khan")
# Out:
# Abdullah Khan

# %% [markdown]
# ### Default Parameter
# We can assign default values to parameters. If the function is called without an argument, it uses the default value:

# %%
def greeting(name = "Abdulah"):
    print(f"Hi, {name}")

# The function is called without argument.
greeting()
# Out:
# Hi, Abdulah

# %% [markdown]
# ### Keyword Arguments
# We can send arguments with the key = value syntax.

# %%
def my_bird_name(bird, name):
    print(f"I have a {bird}")
    print(f"my {bird}'s name is {name}")

# With keyword arguments, the order of the arguments does not matter.
my_bird_name(name = "pito" , bird = "Parrot")
# Out:
# I have a Parrot
# my Parrot's name is pito

# %% [markdown]
# ### Positional Arguments
# When you call a function with arguments without using keywords, they are called positional arguments.
#
# Positional arguments must be in the correct order:

# %%
def my_bird_name(bird, name):
    print(f"I have a {bird}")
    print(f"my {bird}'s name is {name}")


# The order matters with positional arguments:
my_bird_name("Parrot", "pito" )
# Out:
# I have a Parrot
# my Parrot's name is pito

# %% [markdown]
# ### Passing Different Data Types
# We can send any data type as an argument to a function (string, number, list, dictionary, etc.).
#
# The data type will be preserved inside the function:

# %%
def my_function(birds):
    for bird in birds:
        print(bird)

birds_list = ["Eagle", "Parrot", "Pigeon", "Falcon"]
my_function(birds_list)
# Out:
# Eagle
# Parrot
# Pigeon
# Falcon

# %%
# Sending a dictionary as an argument:
def my_details(person):
    print("My name is", person["name"])
    #print("My age is", person["age"])
    print(f"I am {person["age"]} years old")

person_data = {"name": "Abdullah", "age": 23}
my_details(person_data)
# Out:
# My name is Abdullah
# I am 23 years old

# %% [markdown]
# ### Returning Different Data Types
# Functions can return any data type, including lists, tuples, dictionaries, and more.

# %%
# A function that returns a list:
def my_birds():
    return ["Eagle", "Parrot", "Falcon"]

birds_list = my_birds()
print(birds_list[0])
print(birds_list[2])
# Out:
# Eagle
# Falcon

# %%
# A function that returns a tuple:
def my_number():
  return (10, 20)

num1, num2 = my_number()
print(num1)
print(num2)
# Out:
# 10
# 20
