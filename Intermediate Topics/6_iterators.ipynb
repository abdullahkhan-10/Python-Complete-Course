# %% [markdown]
# # Python Iterators
# An iterator is an object that contains a countable number of values.
#
# Lists, tuples, dictionaries, and sets are all iterable objects. They are iterable containers which you can get an iterator from.
#
# All these objects have a iter() method which is used to get an iterator

# %%
birds_tuple = ("Falcon", "Eagle", "Pigeon", "Parrot")

my_iterator = iter(birds_tuple)

print(next(my_iterator))
print(next(my_iterator))
print(next(my_iterator))
print(next(my_iterator))
# Out:
# Falcon
# Eagle
# Pigeon
# Parrot

# %%
# Strings are also iterable objects, containing a sequence of characters:

# %%
name = "Abdullah"
my_iterator = iter(name)

print(next(my_iterator))
print(next(my_iterator))
print(next(my_iterator))
print(next(my_iterator))
print(next(my_iterator))
# Out:
# A
# b
# d
# u
# l

# %% [markdown]
# # Looping Through an Iterator
# We can also use a for loop to iterate through an iterable object:

# %%
birds_tuple = ("Falcon", "Eagle", "Pigeon", "Parrot")

for bird in birds_tuple:
    print(bird)

#Note. The for loop actually creates an iterator object and executes the next() method for each loop.
# Out:
# Falcon
# Eagle
# Pigeon
# Parrot

# %%
# Iterate the characters of a string:

name = "Khan"

for x in name:
    print(x)
# Out:
# K
# h
# a
# n

# %% [markdown]
# # Create an Iterator
# To create an object/class as an iterator you have to implement the methods __iter__() and __next__() to your object.
#
# The __iter__() method acts similar, you can do operations (initializing etc.), but must always return the iterator object itself.
#
# The __next__() method also allows you to do operations, and must return the next item in the sequence
#
# We will learn in the Python Classes/Objects chapter
