# %% [markdown]
# # Pandas Introduction
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %% [markdown]
# ## Why Use Pandas
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.

# %% [markdown]
# ### Import Pandas
# In order to work with pandas we have to import it.

# %%
import pandas as pd

private_jet = {
    "jets" : ["Gulfstream", "Desault", "Bombardier"],
    "models" : ["2025", "2023","2021"]
}

# Access the data through pandas
my_jets = pd.DataFrame(private_jet)

print(my_jets)
# Out:
#          jets models
# 0  Gulfstream   2025
# 1     Desault   2023
# 2  Bombardier   2021

# %% [markdown]
# ### Checking Pandas Version
# To check the current version of pandas we use __version__ attribute.

# %%
cr_version = pd.__version__

print(cr_version)
# Out:
# 2.2.3

# %% [markdown]
# ### Load and Read Files.
# We can load, read and manipulate files like .csv, .json and .xlsx in pandas.

# %%
df = pd.read_csv("industry.csv")

#print(df.to_string())
print(df.head(10))
# Out:
#                         Industry
# 0             Accounting/Finance
# 1   Advertising/Public Relations
# 2             Aerospace/Aviation
# 3  Arts/Entertainment/Publishing
# 4                     Automotive
# 5               Banking/Mortgage
# 6           Business Development
# 7           Business Opportunity
# 8        Clerical/Administrative
# 9        Construction/Facilities
