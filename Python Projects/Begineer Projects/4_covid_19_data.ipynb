# %% [markdown]
# # Covid 19 Data Analysis
#
# In this project we will analyze the data of widely spread pandemic covid 19, To see which country has affected the most.
#
# I have taken a small data from the original dataset of 19000 rows.

# %%
import pandas as pd

# %%
covid_data = pd.read_csv("4_Covid_19_data.csv")

# %%
covid_data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### 1. count() method
#
# The count() method is used to check the number of no null value in each column.
#
# Null value mean missing value

# %%
covid_data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %% [markdown]
# ### 2. isnull()
#
# The isnull() method is used to check the number of null value in each column.

# %%
covid_data.isnull().sum()

# it show that "State" column has 181 nul value mean missing value
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64
